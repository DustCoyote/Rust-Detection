# %%
# !git clone https://github.com/MaticFuc/ECCV_TransFusion.git
# Out:
# Cloning into 'ECCV_TransFusion'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 86 (delta 31), reused 65 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (86/86), 4.25 MiB | 3.87 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.228-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from ultralytics) (2.3.4)
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Downloading matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: pillow>=7.1.2 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from ultralytics) (12.0.0)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Downloading pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting requests>=2.23.0 (from ultralytics)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: scipy>=1.4.1 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from ultralytics) (2.9.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from ultralytics) (0.24.0)
# Requirement already satisfied: psutil in /home/sercoyote/.local/lib/python3.12/site-packages (from ultralytics) (7.1.3)
# Collecting polars (from ultralytics)
#   Downloading polars-1.35.2-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->ultralytics)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->ultralytics)
#   Downloading fonttools-4.60.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /home/sercoyote/.local/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Collecting pyparsing>=3 (from matplotlib>=3.3.0->ultralytics)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting numpy>=1.23.0 (from ultralytics)
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: six>=1.5 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.23.0->ultralytics)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->ultralytics)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->ultralytics)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->ultralytics)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: filelock in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sercoyote/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Collecting polars-runtime-32==1.35.2 (from polars->ultralytics)
#   Downloading polars_runtime_32-1.35.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Downloading ultralytics-8.3.228-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 2.1 MB/s  0:00:00 eta 0:00:01
# Downloading matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 2.7 MB/s  0:00:03m0:00:0100:01
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 2.7 MB/s  0:00:01 eta 0:00:01
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 2.9 MB/s  0:00:00 eta 0:00:01
# Downloading opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 3.4 MB/s  0:00:19m0:00:0100:01
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 3.3 MB/s  0:00:04m0:00:0100:01
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 2.6 MB/s  0:00:00 eta 0:00:01
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Downloading polars-1.35.2-py3-none-any.whl (783 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.6/783.6 kB 2.2 MB/s  0:00:00 eta 0:00:01
# Downloading polars_runtime_32-1.35.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 MB 3.5 MB/s  0:00:11m0:00:0100:01
# Installing collected packages: urllib3, pyyaml, pyparsing, polars-runtime-32, numpy, kiwisolver, idna, fonttools, cycler, charset_normalizer, certifi, requests, polars, opencv-python, contourpy, matplotlib, ultralytics-thop, ultralytics
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/18 [polars-runtime-32]
#     Found existing installation: numpy 2.3.4━━━━━━━━━━━━━━━━━━  3/18 [polars-runtime-32]
#     Uninstalling numpy-2.3.4:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/18 [numpy]time-32]
#       Successfully uninstalled numpy-2.3.4━━━━━━━━━━━━━━━━━━━━  4/18 [numpy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [ultralytics] [ultralytics]thop]
# Successfully installed certifi-2025.11.12 charset_normalizer-3.4.4 contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 idna-3.11 kiwisolver-1.4.9 matplotlib-3.10.7 numpy-2.2.6 opencv-python-4.12.0.88 polars-1.35.2 polars-runtime-32-1.35.2 pyparsing-3.2.5 pyyaml-6.0.3 requests-2.32.5 ultralytics-8.3.228 ultralytics-thop-2.0.18 urllib3-2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import cv2

# 1. 載入模型
model = YOLO("weights/best-yolov8n.pt")

# 2. 讀取圖片
img = cv2.imread("test_media/1.jpg")

# 3. 推論
results = model(img)

# 4. 顯示結果
annotated = results[0].plot()
cv2.imshow("YOLOv8 Detection", annotated)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       2 import cv2
#       4 # 1. 載入模型
# ----> 5 model = YOLO("weights/best-yolov8n.pt")
#       7 # 2. 讀取圖片
#       8 img = cv2.imread("test_media/1.jpg")
#
# File ~/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages/ultralytics/models/yolo/model.py:81, in YOLO.__init__(self, model, task, verbose)
#      78     self.__dict__ = new_instance.__dict__
#      79 else:
#      80     # Continue with default YOLO initialization
# ---> 81     super().__init__(model=model, task=task, verbose=verbose)
#      82     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      83         from ultralytics import RTDETR
#
# File ~/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages/ultralytics/engine/model.py:149, in Model.__init__(self, model, task, verbose)
#     147     self._new(model, task=task, verbose=verbose)
#     148 else:
# --> 149     self._load(model, task=task)
#     151 # Delete super().training for accessing self.model.training
#     152 del self.training
#
# File ~/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages/ultralytics/engine/model.py:288, in Model._load(self, weights, task)
#     285 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     287 if str(weights).rpartition(".")[-1] == "pt":
# --> 288     self.model, self.ckpt = load_checkpoint(weights)
#     289     self.task = self.model.task
#     290     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File ~/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages/ultralytics/nn/tasks.py:1461, in load_checkpoint(weight, device, inplace, fuse)
#    1448 def load_checkpoint(weight, device=None, inplace=True, fuse=False):
#    1449     """Load a single model weights.
#    1450
#    1451     Args:
#    (...)   1459         ckpt (dict): Model checkpoint dictionary.
#    1460     """
# -> 1461     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1462     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1463     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# File ~/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages/ultralytics/nn/tasks.py:1409, in torch_safe_load(weight, safe_only)
#    1407                 ckpt = torch_load(f, pickle_module=safe_pickle)
#    1408         else:
# -> 1409             ckpt = torch_load(file, map_location="cpu")
#    1411 except ModuleNotFoundError as e:  # e.name is missing module name
#    1412     if e.name == "models":
#
# File ~/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages/ultralytics/utils/patches.py:116, in torch_load(*args, **kwargs)
#     113 if TORCH_1_13 and "weights_only" not in kwargs:
#     114     kwargs["weights_only"] = False
# --> 116 return torch.load(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages/torch/serialization.py:1484, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1481 if "encoding" not in pickle_load_args.keys():
#    1482     pickle_load_args["encoding"] = "utf-8"
# -> 1484 with _open_file_like(f, "rb") as opened_file:
#    1485     if _is_zipfile(opened_file):
#    1486         # The zipfile reader is going to advance the current file position.
#    1487         # If we want to actually tail call to torch.jit.load, we need to
#    1488         # reset back to the original position.
#    1489         orig_position = opened_file.tell()
#
# File ~/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages/torch/serialization.py:759, in _open_file_like(name_or_buffer, mode)
#     757 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     758     if _is_path(name_or_buffer):
# --> 759         return _open_file(name_or_buffer, mode)
#     760     else:
#     761         if "w" in mode:
#
# File ~/miniconda3/envs/pytorch_conda/lib/python3.12/site-packages/torch/serialization.py:740, in _open_file.__init__(self, name, mode)
#     739 def __init__(self, name: Union[str, os.PathLike[str]], mode: str) -> None:
# --> 740     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weights/best-yolov8n.pt'

# %%
import os

import torch
import yaml
from ultralytics import YOLO
device = "cuda" if torch.cuda.is_available() else "cpu"
